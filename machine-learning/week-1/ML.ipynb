# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from termcolor import colored as style

# %%
data = pd.read_csv('/content/creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# checking missing values in dataset

# %%
data.isnull().values.any()
# Out:
# True

# %% [markdown]
# handeling the missing values

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.distplot(data.V28)
fig, ax = plt.subplots(figsize=(8,8))
sns.distplot(data.Amount)
fig, ax = plt.subplots(figsize=(8,8))
sns.distplot(data.Class)
# Out:
# <ipython-input-136-cf2ad34288ce>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.V28)
# <ipython-input-136-cf2ad34288ce>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Amount)
# <ipython-input-136-cf2ad34288ce>:6: UserWarning:
#
# ...

# %% [markdown]
# replacing missing values of dataset

# %%
data['V28'].fillna(data['V28'].mean(),inplace=True)

# %%
data['Amount'].fillna(data['Amount'].mean(),inplace=True)
data['Class'].fillna(data['Class'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# check info of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162557 entries, 0 to 162556
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    162557 non-null  float64
#  1   V1      162557 non-null  float64
#  2   V2      162557 non-null  float64
#  3   V3      162557 non-null  float64
#  4   V4      162557 non-null  float64
#  5   V5      162557 non-null  float64
#  6   V6      162557 non-null  float64
#  7   V7      162557 non-null  float64
#  8   V8      162557 non-null  float64
#  9   V9      162557 non-null  float64
#  10  V10     162557 non-null  float64
#  11  V11     162557 non-null  float64
#  12  V12     162557 non-null  float64
#  13  V13     162557 non-null  float64
#  14  V14     162557 non-null  float64
#  15  V15     162557 non-null  float64
#  16  V16     162557 non-null  float64
#  17  V17     162557 non-null  float64
#  18  V18     162557 non-null  float64
#  19  V19     162557 non-null  float64
# ...

# %%
#dribute of legit transaction & fraudulent transaction
data['Class'].value_counts()
# Out:
# Class
# 0.0    162201
# 1.0       356
# Name: count, dtype: int64

# %% [markdown]
# This data set is highly unbalance
# 0->normal
# 1->fraudulent

# %%
#seperate the data for better analysis
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (162201, 30)
# (356, 30)

# %% [markdown]
# check statistical distribution of data

# %%
legit.Amount.describe()
# Out:
# count    162201.000000
# mean         86.929843
# std         244.399427
# min           0.000000
# 25%           5.380000
# 50%          21.350000
# 75%          76.070000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     356.000000
# mean      112.005000
# std       228.517058
# min         0.000000
# 25%         1.000000
# 50%         9.905000
# 75%       102.125000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
data.groupby('Class').mean()
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# Class
# 0.0   -0.185444  0.042135  0.569689  0.124499 -0.191311  0.067595 -0.076600
# 1.0   -6.057284  4.419181 -8.006879  4.902106 -4.402531 -1.445960 -7.057336
#
#              V8        V9       V10  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.038895  0.027552 -0.023568  ...  0.032755 -0.036009 -0.096154
# 1.0    0.778068 -2.884994 -6.671396  ...  0.413879  0.767732 -0.017997
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.025342  0.010510  0.103689  0.014088  0.001871  0.002442   86.929843
# 1.0   -0.045050 -0.073773  0.080805  0.036841  0.181541  0.044143  112.005000
#
# [2 rows x 29 columns]

# %% [markdown]
# Undersampling

# %%
legit_sample=legit.sample(n=356)

# %%
new_data=pd.concat([legit_sample, fraud],axis=0)
new_data.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 7530   -1.344960  1.607285  2.502459  2.767967 -0.093336  0.586971  0.167595
# 3874   -0.484963  1.259518  0.728020  0.526700  0.536415 -1.051708  0.818147
# 86505  -0.387202  1.110434  1.321203 -0.057487  0.124265 -0.642407  0.650322
# 107331  1.226117 -0.077245  0.619905 -0.001029 -0.585332 -0.551047 -0.227146
# 160052 -0.742788  0.641933 -0.150745 -0.091911  0.524772 -1.179541  1.512040
#
#               V8        V9       V10  ...       V21       V22       V23  \
# 7530    0.084712  0.925116  1.500307  ... -0.364552 -0.282218 -0.027845
# 3874   -0.155430 -1.065943 -0.573667  ...  0.062882  0.148239 -0.191359
# 86505   0.045420 -0.729573 -0.359103  ... -0.205276 -0.537264 -0.028154
# 107331 -0.158728  0.256428 -0.224590  ... -0.135079 -0.401489  0.024362
# 160052 -0.398786 -0.271760 -1.144722  ...  0.273748  0.903817 -0.066893
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0.0    356
# 1.0    356
# Name: count, dtype: int64

# %% [markdown]
# #feauture **engineering**

# %%
x=new_data

# %% [markdown]
# #Time Attribute

# %%
if 'Time' in data.columns:
    data.drop('Time',axis=1,inplace=True)
else:
    print("not found")

X = data.drop('Class',axis=1)
Y = data['Class']
X.shape, Y.shape
# Out:
# ((162557, 29), (162557,))

# %% [markdown]
# Normalise the dataset using sandardscaler

# %%
copy_df = data.copy()
from sklearn.preprocessing import StandardScaler

standard = StandardScaler()
amount = copy_df['Amount'].values
copy_df['Amount'] = standard.fit_transform(amount.reshape(-1,1))
X_scaled = copy_df.drop('Class', axis=1)
y_scaled = copy_df['Class']
X_scaled.shape, y_scaled.shape
# Out:
# ((162557, 29), (162557,))

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# #EDA

# %%
# class
class_df=pd.DataFrame(data['Class'].value_counts().rename_axis('Class').reset_index(name='Count'))
class_df['Class'].replace({0:'Normal',1:'Fraud'},inplace=True)

# %%
class_df.head()
# Out:
#     Class   Count
# 0  Normal  162201
# 1   Fraud     356

# %% [markdown]
# #Bar graphs

# %%
fig = plt.figure()
fig.set_figheight(8)
fig.set_figwidth(10)

ax = sns.barplot(x=class_df['Class'],
                 y=class_df['Count'])

ax.bar_label(ax.containers[0], color='red')

ax.set_xticklabels(labels=list(class_df['Class']), c='blue', rotation=0, fontsize=10, fontweight='bold')
labels, location = plt.yticks()
ax.set_yticklabels(labels=labels.astype(int), c='blue', fontsize=8, fontweight='bold')

plt.xlabel(xlabel='Type of Transactions', fontsize=14, fontweight='bold').set_color('purple')
plt.ylabel(ylabel='Frequency', fontsize=14, fontweight='bold').set_color('purple')
plt.title(label='Count Values of Normal vs Fraud Class', fontsize=24, fontweight='bold').set_color('blue')

plt.show()
# Out:
# <ipython-input-260-08c3891e033c>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels=list(class_df['Class']), c='blue', rotation=0, fontsize=10, fontweight='bold')
# <ipython-input-260-08c3891e033c>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(labels=labels.astype(int), c='blue', fontsize=8, fontweight='bold')

# %% [markdown]
# Histogram

# %%
df = pd.read_csv('creditcard.csv')


fraud = df[df['Class'] == 1]
normal = df[df['Class'] == 0]

fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               sharex=True)
fig.suptitle("Variation in Amount per Class", color='green')
bins=50
ax0.hist(fraud['Amount'], bins=bins, color='yellow')
ax0.set_title('Fraud')
ax0.set_ylim(0, 100)
ax0.set_ylabel('Number of Transactions')

ax1.hist(normal['Amount'], bins=bins, color='yellow')
ax1.set_title('Normal')
ax1.set_ylabel('Number of Transactions')

plt.xlim(0, 20000)
plt.xlabel('Amount')
plt.yscale('log')
plt.show()

# %% [markdown]
# #**normalise** data

# %%
from sklearn.ensemble import RandomForestClassifier
def RF_model(X,Y):
    print("Spliting Datasets.")
    from sklearn.model_selection import train_test_split
    np.random.seed(42)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.2)
    print("Successfully splitted!")

    print("Model Fit.")
    rf = RandomForestClassifier()
    rf.fit(X_train, Y_train)
    print("Successfully model fitted!")

    from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
    print("Training Prediction--")
    y_preds = rf.predict(X_train)
    print(f"Classfifcation Report:\n\n{classification_report(Y_train, y_preds)}\n\n")

    cf_matrix = confusion_matrix(Y_train, y_preds)

    fig, ax = plt.subplots(figsize=(6,4))
    sns.heatmap(cf_matrix, annot=True, cmap='coolwarm', fmt='g')
    fig.suptitle(t="Confusion Matrix of Training Datasets",
                 color="orange",
                 fontsize=16);
    ax.set(xlabel="Predicted Label",
           ylabel="Actual Label");

    print(f"Accuracy Score:\n\n{accuracy_score(Y_train, y_preds)*100:2f}%\n")

    print("Test Prediction--")

    Y_preds = rf.predict(X_test) # Fixed: Using Y_preds instead of y_preds
    print(f"Classfifcation Report:\n\n{classification_report(Y_test, Y_preds)}\n\n")

    cf_matrix = confusion_matrix(Y_test, Y_preds)

    fig, ax = plt.subplots(figsize=(6,4))
    sns.heatmap(cf_matrix, annot=True, cmap='coolwarm', fmt='g')
    fig.suptitle(t="Confusion Matrix of Testing Datasets",
                 color="orange",
                 fontsize=16);
    ax.set(xlabel="Predicted Label",
           ylabel="Actual Label");

    print(f"Accuracy Score:\n\n{accuracy_score(Y_test, Y_preds)*100:2f}%\n")

# %%
new_var = RF_model(data.drop('Class', axis=1), data['Class'])
# Out:
# Spliting Datasets.
# Successfully splitted!
# Model Fitting.....
# Successfully model fitted!
# Training Prediction--
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    129759
#          1.0       1.00      1.00      1.00       286
#
#     accuracy                           1.00    130045
#    macro avg       1.00      1.00      1.00    130045
# weighted avg       1.00      1.00      1.00    130045
#
#
#
# Accuracy Score:
#
# 99.999231%
#
# Test Prediction--
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     32442
#          1.0       0.98      0.81      0.89        70
#
#     accuracy                           1.00     32512
#    macro avg       0.99      0.91      0.95     32512
# weighted avg       1.00      1.00      1.00     32512
#
#
#
# Accuracy Score:
#
# 99.956939%

# %% [markdown]
# #**SMOTE**

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(sampling_strategy='minority', random_state=42)

# %%
X_smote, Y_smote = sm.fit_resample(data.drop('Class', axis=1), data['Class'])
smote_df = pd.concat([pd.DataFrame(X_smote), pd.DataFrame(Y_smote)], axis=1)
X_smote.shape
# Out:
# (324402, 29)

# %%
smote_df.Class.value_counts()
# Out:
# Class
# 0.0    162201
# 1.0    162201
# Name: count, dtype: int64

# %%
RF_model(X_smote, Y_smote)
# Out:
# Spliting Datasets.
# Successfully splitted!
# Model Fitting.....
# Successfully model fitted!
# Training Prediction--
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    129808
#          1.0       1.00      1.00      1.00    129713
#
#     accuracy                           1.00    259521
#    macro avg       1.00      1.00      1.00    259521
# weighted avg       1.00      1.00      1.00    259521
#
#
#
# Accuracy Score:
#
# 100.000000%
#
# Test Prediction--
# Classfifcation Report:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     32393
#          1.0       1.00      1.00      1.00     32488
#
#     accuracy                           1.00     64881
#    macro avg       1.00      1.00      1.00     64881
# weighted avg       1.00      1.00      1.00     64881
#
#
#
# Accuracy Score:
#
# 99.984587%

# %% [markdown]
# #**model evaluation**

# %%
#accuracy test(train data)
from sklearn.metrics import accuracy_score
x_train = X_smote
Y_train = Y_smote
X_train_prediction = model.predict(x_train)
data_accuracy = accuracy_score(X_train_prediction, Y_train)

print(data_accuracy)
# Out:
# 0.9639521334640354

# %%
#accuracy test(test data)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_smote, Y_smote, test_size=0.2, random_state=42)
X_test_prediction = model.predict(X_test)  # Predict on the test data
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

print(test_data_accuracy)
# Out:
# 0.9640572740864043
